# %%
# Importando a bibliotecas
from math import sqrt
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
# Criando o dataset - questão 3
X, y = make_blobs(n_samples=500, centers=20, random_state=999)
plt.scatter(X[:,0], X[:,1])

# %%
# A partir do WCSS determinar o número de clusters
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
n = optimal_number_of_clusters(wcss)
print(f'Numero de clusters: ', n)
# Out:
# Numero de clusters:  4

# %%
# questão 4
kmeans = KMeans(n_clusters=1, init='random') # seta o número de cluster para 1, conforme a pergunta 4
kmeans.fit(X) 

kmeans.cluster_centers_ # mostra o resultado da pergunta 4 (array([[ 0.02618523, -1.30384304]]))
# Out:
# array([[ 0.02618523, -1.30384304]])

# %%
# questões 5 e 6

wcss = []	
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    print('Clusters:', i, ' / wcss =', wcss[i-1]) # o output do primeiro cluster mostra o resultado da pergunta 5 (Clusters: 1  / wcss = 31547.372471390485) e o output do quinto cluster mostra o resultado da pergunta 6 (Clusters: 5  / wcss = 4717.404091931214)

plt.plot(range(1, 20), wcss)
plt.plot([1, 19],[wcss[0], wcss[len(wcss)-1]])
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid()
plt.show()
# Out:
# Clusters: 1  / wcss = 31547.372471390485
# Clusters: 2  / wcss = 16949.214472147927
# Clusters: 3  / wcss = 9464.847250570496
# Clusters: 4  / wcss = 6005.101775346179
# Clusters: 5  / wcss = 4717.404091931214
# Clusters: 6  / wcss = 3667.860593372465
# Clusters: 7  / wcss = 2975.713631686225
# Clusters: 8  / wcss = 2490.8713955724124
# Clusters: 9  / wcss = 2049.8679429014373
# Clusters: 10  / wcss = 1841.8381644426468
# Clusters: 11  / wcss = 1648.9943608775416
# Clusters: 12  / wcss = 1475.7997312173013
# Clusters: 13  / wcss = 1327.7143967829456
# Clusters: 14  / wcss = 1165.2099572641814
# Clusters: 15  / wcss = 1065.5505173333581
# Clusters: 16  / wcss = 987.3417319487319
# Clusters: 17  / wcss = 917.9843370021966
# Clusters: 18  / wcss = 858.6553641848552
# Clusters: 19  / wcss = 785.8899200751118

# %%
# questão 7


wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
n = optimal_number_of_clusters(wcss)
print(n)
# Out:
# 4
